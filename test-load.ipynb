# %%
import os

import numpy as np
import tensorflow as tf

from PIL import Image

# %%
bim = open('./test.jpg', 'rb').read()

# %%
m = tf.saved_model.load('./example/preprocess_550x800/1/model.saved_model/')

# %%
img_normed = m([bim]).numpy()
r, g, b = img_normed[0]
r = r * 0.229 + 0.485
g = g * 0.224 + 0.456
b = b * 0.225 + 0.406

Image.fromarray(np.transpose((np.stack([r, g, b]) * 255).astype('uint8'), (1, 2, 0)))
# Out:
# <PIL.Image.Image image mode=RGB size=800x550 at 0x2564AE92A20>
